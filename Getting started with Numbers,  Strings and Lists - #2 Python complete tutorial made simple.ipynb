# %% [markdown]
# # Amin M. Boulouma Blog

# %% [markdown]
# ## Getting started with Numbers, Strings and Lists - #2 Python complete tutorial made simple

# %% [markdown]
# Hosted by Amin M. Boulouma, contact and questions: [amine.boulouma.com](https://amine.boulouma.com)
# - Python tutorial made simple: https://www.youtube.com/channel/UCOZbokHO727qeStxeYSKMUQ
# - Source code: https://amboulouma.com/python-tutorial
# - Github: https://github.com/amboulouma/python-complete-tutorial-made-simple

# %% [markdown]
# ### Getting started

# %%
# this is the first comment

# n and text is a variable
n = 1  # and this is the second comment
          # ... and now a third!
    
text = "This is some text"

# %%
n
# Out:
# 1

# %%
text
# Out:
# 'This is some text'

# %% [markdown]
# ### Programming a calculator

# %% [markdown]
# #### Numbers

# %%
2 + 2
# Out:
# 4

# %%
50 - 5*6
# Out:
# 20

# %%
(50 - 5*6) / 4
# Out:
# 5.0

# %%
8 / 5  # division always returns a floating point number
# Out:
# 1.6

# %%
17 / 3  # classic division returns a float
# Out:
# 5.666666666666667

# %%
17 // 3  # floor division discards the fractional part
# Out:
# 5

# %%
17 % 3  # the % operator returns the remainder of the division
# Out:
# 2

# %%
5 * 3 + 2  # floored quotient * divisor + remainder
# Out:
# 17

# %%
5 ** 2  # 5 squared
# Out:
# 25

# %%
2 ** 7  # 2 to the power of 7
# Out:
# 128

# %%
width = 20
height = 5 * 9

width * height
# Out:
# 900

# %%
m  # try to access an undefined variable
# Out:
# -------------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-17-0dba2ac38253> in <module>
# ----> 1 m  # try to access an undefined variable
#
# NameError: name 'm' is not defined

# %%
4 * 3.75 - 1
# Out:
# 14.0

# %%
tax = 12.5 / 100
price = 100.50
price * tax
# Out:
# 12.5625

# %%
price + _
# Out:
# 113.0625

# %%
round(_, 2)
# Out:
# 113.06

# %% [markdown]
# #### Strings

# %%
'hello world' # single quotes
# Out:
# 'hello world'

# %%
'doesn\'t' # use \' to escape the single quote
# Out:
# "doesn't"

# %%
"doesn't"  # or use double quotes instead
# Out:
# "doesn't"

# %%
'"Yes," they said.'
# Out:
# '"Yes," they said.'

# %%
'"Isn\'t," they said.'
# Out:
# '"Isn\'t," they said.'

# %%
'"Isn\'t," they said.'
# Out:
# '"Isn\'t," they said.'

# %%
print('"Isn\'t," they said.')
# Out:
# "Isn't," they said.

# %%
s = 'First line.\nSecond line.'  # \n means newline

# %%
s  # without print(), \n is included in the output
# Out:
# 'First line.\nSecond line.'

# %%
print(s)  # with print(), \n produces a new line
# Out:
# First line.
# Second line.

# %%
print('C:\some\name')  # here \n means newline!
# Out:
# C:\some
# ame

# %%
print(r'C:\some\name')  # note the r before the quote, r for raw string
# Out:
# C:\some\name

# %%
print("""\
Usage: thingy [OPTIONS]
     -h                        Display this usage message
     -H hostname               Hostname to connect to
""")
# Out:
# Usage: thingy [OPTIONS]
#      -h                        Display this usage message
#      -H hostname               Hostname to connect to

# %%
# 3 times 'un', followed by 'ium'
3 * 'un' + 'ium'
# Out:
# 'unununium'

# %%
'Py' 'thon'
# Out:
# 'Python'

# %%
text = ('Put several strings within parentheses '
        'to have them joined together.')

# %%
text
# Out:
# 'Put several strings within parentheses to have them joined together.'

# %%
prefix = 'Py'

# %%
prefix 'thon'  # can't concatenate a variable and a string literal
# Out:
#   File "<ipython-input-46-c5901e312aa3>", line 1
#     prefix 'thon'  # can't concatenate a variable and a string literal
#            ^
# SyntaxError: invalid syntax

# %%
('un' * 3) 'ium'
# Out:
#   File "<ipython-input-47-f4764cbe42a8>", line 1
#     ('un' * 3) 'ium'
#                ^
# SyntaxError: invalid syntax

# %%
prefix + 'thon'
# Out:
# 'Python'

# %%
word = 'Python'

# %%
word[0] # character in position 0
# Out:
# 'P'

# %%
word[5]  # character in position 5
# Out:
# 'n'

# %%
word[-1]  # last character
# Out:
# 'n'

# %%
word[-2]  # second-last character
# Out:
# 'o'

# %%
word[-6]
# Out:
# 'P'

# %%
word[0:2]
# Out:
# 'Py'

# %%
word[2:5]
# Out:
# 'tho'

# %%
word[:2] + word[2:]
# Out:
# 'Python'

# %%
word[:4] + word[4:] # i
# Out:
# 'Python'

# %%
word[:2]
# Out:
# 'Py'

# %%
word[4:]
# Out:
# 'on'

# %%
word[-2:]

# %% [markdown]
#  +---+---+---+---+---+---+
#  | P | y | t | h | o | n |
#  +---+---+---+---+---+---+
#  0   1   2   3   4   5   6
# -6  -5  -4  -3  -2  -1

# %%
word[42]  # the word only has 6 characters
# Out:
# -------------------------
# IndexErrorTraceback (most recent call last)
# <ipython-input-61-469c6d99b5b2> in <module>
# ----> 1 word[42]  # the word only has 6 characters
#
# IndexError: string index out of range

# %%
word[4:42]
# Out:
# 'on'

# %%
word[42:]
# Out:
# ''

# %%
word[0] = 'J'
# Out:
# -------------------------
# TypeErrorTraceback (most recent call last)
# <ipython-input-64-91a956888ca7> in <module>
# ----> 1 word[0] = 'J'
#
# TypeError: 'str' object does not support item assignment

# %%
word[2:] = 'py'
# Out:
# -------------------------
# TypeErrorTraceback (most recent call last)
# <ipython-input-65-6488bbf78f5a> in <module>
# ----> 1 word[2:] = 'py'
#
# TypeError: 'str' object does not support item assignment

# %%
'J' + word[1:]
# Out:
# 'Jython'

# %%
word[:2] + 'py'
# Out:
# 'Pypy'

# %%
s = 'hello'
len(s)
# Out:
# 5

# %% [markdown]
# ### Lists

# %%
squares = [1, 4, 9, 16, 25]
squares
# Out:
# [1, 4, 9, 16, 25]

# %%
squares[0]  # indexing returns the item
# Out:
# 1

# %%
squares[-1]
# Out:
# 25

# %%
squares[-3:]  # slicing returns a new list
# Out:
# [9, 16, 25]

# %%
squares[:] # shallow copy of squares
# Out:
# [1, 4, 9, 16, 25]

# %%
squares + [36, 49, 64, 81, 100] # Concatenation
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
cubes = [1, 8, 27, 65, 125]  # something's wrong here
4 ** 3  # the cube of 4 is 64, not 65!
# Out:
# 64

# %%
cubes[3] = 64  # replace the wrong value
cubes
# Out:
# [1, 8, 27, 64, 125]

# %%
cubes.append(216)  # add the cube of 6
cubes.append(7 ** 3)  # and the cube of 7
cubes
# Out:
# [1, 8, 27, 64, 125, 216, 343]

# %%
letters = ['a', 'b', 'c', 'd', 'e', 'f', 'g']
letters
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
# replace some values
letters[2:5] = ['C', 'D', 'E']
letters
# Out:
# ['a', 'b', 'C', 'D', 'E', 'f', 'g']

# %%
# now remove them
letters[2:5] = []
letters
# Out:
# ['a', 'b', 'f', 'g']

# %%
# clear the list by replacing all the elements with an empty list
letters[:] = []
letters
# Out:
# []

# %%
letters = ['a', 'b', 'c', 'd']
len(letters)
# Out:
# 4

# %%
a = ['a', 'b', 'c']
n = [1, 2, 3]
x = [a, n]
x
# Out:
# [['a', 'b', 'c'], [1, 2, 3]]

# %%
x[0]
# Out:
# ['a', 'b', 'c']

# %%
x[0][1]
# Out:
# 'b'

# %% [markdown]
# ### More on programming

# %%
# Fibonacci series:
# the sum of two elements defines the next
a, b = 0, 1
while a < 10:
     print(a)
     a, b = b, a+b
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8
